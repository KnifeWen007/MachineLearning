# %%
# 基础库
import sys  # 显式导入sys，替代np.sys消除提示
import numpy as np
import pandas as pd
import scipy
# 可视化
import matplotlib.pyplot as plt
import seaborn as sns
# 机器学习核心
import sklearn
# 仅保留需要的导入（删除未使用的datasets/ensemble，消除"未使用导入"提示）
import xgboost as xgb
import lightgbm as lgb
import catboost as cb
# 交互式工具
import jupyter

# 可选：Polars（若安装成功）
# 提前定义pl为None，消除"try中定义未在except中"的提示
pl = None
try:
    import polars as pl

    print(f'✅ Polars 版本：{pl.__version__}')
except ImportError:
    pl = None  # 显式赋值，消除提示
    print('⚠️ Polars 未安装（可选，不影响核心机器学习）')


# 封装版本打印函数，避免属性不存在报错，同时消除编辑器提示
def get_version(module, default="未知版本"):
    """获取库版本，兼容无__version__属性的情况"""
    return getattr(module, "__version__", default)


# 打印核心库版本，确认兼容性
print('✅ 所有核心机器学习库导入成功！')
print(f'Python 版本：{sys.version.split()[0]}')  # 用sys替代np.sys
print(f'NumPy 版本：{get_version(np)}')
print(f'Pandas 版本：{get_version(pd)}')
print(f'Scikit-learn 版本：{get_version(sklearn)}')
print(f'SciPy 版本：{get_version(scipy)}')
print(f'Matplotlib 版本：{get_version(plt)}')
print(f'Seaborn 版本：{get_version(sns)}')
print(f'XGBoost 版本：{get_version(xgb)}')
print(f'LightGBM 版本：{get_version(lgb)}')
print(f'CatBoost 版本：{get_version(cb)}')
print(f'Jupyter 版本：{get_version(jupyter)}')
# Out:
# ✅ Polars 版本：1.36.0
# ✅ 所有核心机器学习库导入成功！
# Python 版本：3.10.19
# NumPy 版本：1.26.4
# Pandas 版本：2.3.3
# Scikit-learn 版本：1.7.2
# SciPy 版本：1.15.3
# Matplotlib 版本：未知版本
# Seaborn 版本：0.13.2
# XGBoost 版本：3.1.2
# LightGBM 版本：4.6.0
# CatBoost 版本：1.2.7
# Jupyter 版本：未知版本
